# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/EY_batch_7_09-Sept/blob/main/Lab_02_Weights_and_bias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Welcome back!

# %% [markdown]
# In this lab, we will observe how weights and bias are trained over epochs.

# %% [markdown]
# Let's begin with importing the libraries and read the dataset. We will also break the dataset into features and labels.

# %%
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
#IGNORE ANY WARNINGS THAT MAY APPEAR ON THIS CELL

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data/data.csv')

# %%
# PERMUTATION BASED FEATURE SELECTION-> {x1, x2, x3} ->
# {x1} {x2} { x1 x2} {x3}.... {x3 x1}.... {x1 x2 x3}

# DIMENSION REDUCTION -> principal component analysis, linear discriminant analysis

# %%
x = data[['radius_mean', 'perimeter_mean']]
y = data[['diagnosis']]

# %% [markdown]
# We are using the same dataset as in the last lab- view the inputs and labels.

# %%
x.head()
# Out:
#    radius_mean  perimeter_mean
# 0        17.99          122.80
# 1        20.57          132.90
# 2        19.69          130.00
# 3        11.42           77.58
# 4        20.29          135.10

# %%
y.head()
# Out:
#   diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M

# %% [markdown]
# Using the same process as the last lab, we will normalize the inputs, and encode the labels.

# %%
#Normalize Input
stats = x.describe().T
mu, sigma = stats['mean'], stats['std']

# %%
x_norm = (x-mu)/sigma

# %%
x_norm
# Out:
#      radius_mean  perimeter_mean
# 0       1.096100        1.268817
# 1       1.828212        1.684473
# 2       1.578499        1.565126
# 3      -0.768233       -0.592166
# 4       1.748758        1.775011
# ..           ...             ...
# 564     2.109139        2.058974
# 565     1.703356        1.614511
# 566     0.701667        0.672084
# 567     1.836725        1.980781
# 568    -1.806811       -1.812793
#
# [569 rows x 2 columns]

# %%
rule = lambda val: 1 if val=='M' else 0

# %%
y=y['diagnosis'].apply(rule)

# %%
y.tail()
# Out:
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, dtype: int64

# %% [markdown]
# Now we will proceed to splitting the data. No changes so far-

# %%
HP_epochs = 200
HP_batch_size = 16
HP_lr = 0.001

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x_norm,y,random_state=42)

# %% [markdown]
# Our dataset is small. But for big data, or larger datasets, we can use TensorFlow's Dataset API.
# <br/>
# We additionally shuffle the dataset to provide randomness.
#
# Because we are going to simulate the training process over epochs, we will also repeat our dataset.
#
# We will also divide our data into fixed size batches.

# %%
celldata = tf.data.Dataset.from_tensor_slices((xtrain,ytrain))
celldata = celldata.shuffle(100).repeat(HP_epochs).batch(HP_batch_size)

# %% [markdown]
# This is the simplest way to create a dataset.
#
# dataset = tf.data.Dataset.from_tensor_slices(any_tensor_or_numpy_array_or_pandas_dataset)

# %% [markdown]
# Now we will place an iterator on top of our dataset to loop into the actual data.

# %%
itr = celldata.__iter__()
#IGNORE ANY WARNINGS THAT MAY APPEAR ON THIS CELL

# %% [markdown]
# Now, we will initialize our weights and bias. We are initializing the weights with random numbers, normally distributed from the mean 0, with a standard deviation of 0.5.

# %%
# we have only 2 features and 1 label
# One weight for each feature
w = tf.random.normal( ( 2 , 1 ), mean = 0, stddev =0.5,dtype=tf.dtypes.double )
# One bias for every output
# our only output is the label prediction on 1 layer
b = 0

# %% [markdown]
# Have a look at the initial weights

# %%
print(w)
# Out:
# tf.Tensor(
# [[-0.04168642]
#  [ 0.48922487]], shape=(2, 1), dtype=float64)

# %%
# define an empty array to store all the errors
# errors will be generated from each training simulation
err = []

# %% [markdown]
# Let's define a dummy classifier to encode our predictions into 1 and 0

# %%
def myclassifier(vals):
  res = []
  rule = lambda r: 1.0 if r>=0.5 else 0.0
  for val in vals:
    res.append(rule(val))
  return res

# %% [markdown]
# And let's begin the training simulation!

# %%
# real values: 2 1  2  1  2  1
# predicted v: 1 2  2  1  1. 2

# error-> 1, -1, 0, 0 , 1, -1
# total error= 0
# 2 solutions->
# absolute value=> 1, 1, 0, 0, 1, 1
# square value=> 1,1,0,0,1,1

# %%
#y = mx + c

#weights * inputs + bias

#[matrix] * matrix + matrix

# DOT, CROSS

# %% [markdown]
# TensorFlow functions to observe
#
#
# *   tensordot - returns dot product
# *   cast - datatype casting on tensors
# *   reduce_mean - mean of TensorFlow datasets

# %%
itrs_per_epoch = int(len(xtrain)/HP_batch_size)
# Each iteration represents 1 epoch
for i in range(HP_epochs):
  per_iter_err = []
  for j in range(itrs_per_epoch):
    # get data and labels in fixed batch sizes
    data, labels = itr.get_next()

    # simplest representation of ML
    # y = mx + c
    y = tf.tensordot(data, w, axes=1) + b
    # decode the results, and typecast to double
    y = myclassifier(y)
    y = tf.cast(y, tf.dtypes.double)
    # typecast the known labels to double
    labels = tf.cast(labels, tf.dtypes.double)
    # calculate the error
    avg_error = tf.reduce_mean(tf.square(y - labels))
    per_iter_err.append(avg_error)
    mse_derivative = tf.reduce_mean(2 * ( y - labels ))

    # update the weights and bias for the next epoch
    weight_update = tf.reduce_mean(mse_derivative*data)
    bias_update = tf.reduce_mean(mse_derivative)

    w = w - HP_lr * weight_update # v= u + at -> final_weight = init_w +- LR*update
    b = b - HP_lr * bias_update
    # end of iteration simulation

  final_epoch_error = np.array(per_iter_err).mean()
  err.append(final_epoch_error)
  #end of epoch simulation

  print('****')
  print('For epoch ',i+1,', the weights = ', w)
# Out:
# ****
# For epoch  1 , the weights =  tf.Tensor(
# [[-0.0415093 ]
#  [ 0.48940199]], shape=(2, 1), dtype=float64)
# ****
# For epoch  2 , the weights =  tf.Tensor(
# [[-0.0416018 ]
#  [ 0.48930949]], shape=(2, 1), dtype=float64)
# ****
# For epoch  3 , the weights =  tf.Tensor(
# [[-0.04207212]
#  [ 0.48883917]], shape=(2, 1), dtype=float64)
# ****
# For epoch  4 , the weights =  tf.Tensor(
# [[-0.04190454]
#  [ 0.48900674]], shape=(2, 1), dtype=float64)
# ****
# For epoch  5 , the weights =  tf.Tensor(
# [[-0.04195368]
#  [ 0.48895761]], shape=(2, 1), dtype=float64)
# ****
# For epoch  6 , the weights =  tf.Tensor(
# [[-0.04179826]
#  [ 0.48911303]], shape=(2, 1), dtype=float64)
# ****
# For epoch  7 , the weights =  tf.Tensor(
# [[-0.04207059]
#  [ 0.4888407 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  8 , the weights =  tf.Tensor(
# [[-0.04189915]
#  [ 0.48901214]], shape=(2, 1), dtype=float64)
# ****
# For epoch  9 , the weights =  tf.Tensor(
# [[-0.0417281 ]
#  [ 0.48918319]], shape=(2, 1), dtype=float64)
# ****
# For epoch  10 , the weights =  tf.Tensor(
# [[-0.04224481]
#  [ 0.48866648]], shape=(2, 1), dtype=float64)
# ****
# For epoch  11 , the weights =  tf.Tensor(
# [[-0.04237874]
#  [ 0.48853255]], shape=(2, 1), dtype=float64)
# ****
# For epoch  12 , the weights =  tf.Tensor(
# [[-0.04197855]
#  [ 0.48893274]], shape=(2, 1), dtype=float64)
# ****
# For epoch  13 , the weights =  tf.Tensor(
# [[-0.04215165]
#  [ 0.48875963]], shape=(2, 1), dtype=float64)
# ****
# For epoch  14 , the weights =  tf.Tensor(
# [[-0.04215786]
#  [ 0.48875343]], shape=(2, 1), dtype=float64)
# ****
# For epoch  15 , the weights =  tf.Tensor(
# [[-0.04180076]
#  [ 0.48911053]], shape=(2, 1), dtype=float64)
# ****
# For epoch  16 , the weights =  tf.Tensor(
# [[-0.04152082]
#  [ 0.48939047]], shape=(2, 1), dtype=float64)
# ****
# For epoch  17 , the weights =  tf.Tensor(
# [[-0.04157779]
#  [ 0.48933349]], shape=(2, 1), dtype=float64)
# ****
# For epoch  18 , the weights =  tf.Tensor(
# [[-0.04126155]
#  [ 0.48964973]], shape=(2, 1), dtype=float64)
# ****
# For epoch  19 , the weights =  tf.Tensor(
# [[-0.04141878]
#  [ 0.48949251]], shape=(2, 1), dtype=float64)
# ****
# For epoch  20 , the weights =  tf.Tensor(
# [[-0.04150878]
#  [ 0.48940251]], shape=(2, 1), dtype=float64)
# ****
# For epoch  21 , the weights =  tf.Tensor(
# [[-0.04147744]
#  [ 0.48943384]], shape=(2, 1), dtype=float64)
# ****
# For epoch  22 , the weights =  tf.Tensor(
# [[-0.04140677]
#  [ 0.48950452]], shape=(2, 1), dtype=float64)
# ****
# For epoch  23 , the weights =  tf.Tensor(
# [[-0.04168516]
#  [ 0.48922612]], shape=(2, 1), dtype=float64)
# ****
# For epoch  24 , the weights =  tf.Tensor(
# [[-0.04145044]
#  [ 0.48946085]], shape=(2, 1), dtype=float64)
# ****
# For epoch  25 , the weights =  tf.Tensor(
# [[-0.04092703]
#  [ 0.48998426]], shape=(2, 1), dtype=float64)
# ****
# For epoch  26 , the weights =  tf.Tensor(
# [[-0.04080998]
#  [ 0.49010131]], shape=(2, 1), dtype=float64)
# ****
# For epoch  27 , the weights =  tf.Tensor(
# [[-0.04092064]
#  [ 0.48999064]], shape=(2, 1), dtype=float64)
# ****
# For epoch  28 , the weights =  tf.Tensor(
# [[-0.04084055]
#  [ 0.49007073]], shape=(2, 1), dtype=float64)
# ****
# For epoch  29 , the weights =  tf.Tensor(
# [[-0.04103659]
#  [ 0.4898747 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  30 , the weights =  tf.Tensor(
# [[-0.04108671]
#  [ 0.48982458]], shape=(2, 1), dtype=float64)
# ****
# For epoch  31 , the weights =  tf.Tensor(
# [[-0.0416802 ]
#  [ 0.48923109]], shape=(2, 1), dtype=float64)
# ****
# For epoch  32 , the weights =  tf.Tensor(
# [[-0.04155909]
#  [ 0.48935219]], shape=(2, 1), dtype=float64)
# ****
# For epoch  33 , the weights =  tf.Tensor(
# [[-0.04199491]
#  [ 0.48891638]], shape=(2, 1), dtype=float64)
# ****
# For epoch  34 , the weights =  tf.Tensor(
# [[-0.04157018]
#  [ 0.4893411 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  35 , the weights =  tf.Tensor(
# [[-0.04105826]
#  [ 0.48985303]], shape=(2, 1), dtype=float64)
# ****
# For epoch  36 , the weights =  tf.Tensor(
# [[-0.04116447]
#  [ 0.48974682]], shape=(2, 1), dtype=float64)
# ****
# For epoch  37 , the weights =  tf.Tensor(
# [[-0.04131217]
#  [ 0.48959912]], shape=(2, 1), dtype=float64)
# ****
# For epoch  38 , the weights =  tf.Tensor(
# [[-0.04110841]
#  [ 0.48980287]], shape=(2, 1), dtype=float64)
# ****
# For epoch  39 , the weights =  tf.Tensor(
# [[-0.0412248 ]
#  [ 0.48968649]], shape=(2, 1), dtype=float64)
# ****
# For epoch  40 , the weights =  tf.Tensor(
# [[-0.04135463]
#  [ 0.48955666]], shape=(2, 1), dtype=float64)
# ****
# For epoch  41 , the weights =  tf.Tensor(
# [[-0.04186354]
#  [ 0.48904775]], shape=(2, 1), dtype=float64)
# ****
# For epoch  42 , the weights =  tf.Tensor(
# [[-0.04188589]
#  [ 0.4890254 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  43 , the weights =  tf.Tensor(
# [[-0.04179385]
#  [ 0.48911744]], shape=(2, 1), dtype=float64)
# ****
# For epoch  44 , the weights =  tf.Tensor(
# [[-0.04187479]
#  [ 0.4890365 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  45 , the weights =  tf.Tensor(
# [[-0.04237963]
#  [ 0.48853166]], shape=(2, 1), dtype=float64)
# ****
# For epoch  46 , the weights =  tf.Tensor(
# [[-0.0421127 ]
#  [ 0.48879859]], shape=(2, 1), dtype=float64)
# ****
# For epoch  47 , the weights =  tf.Tensor(
# [[-0.04185923]
#  [ 0.48905206]], shape=(2, 1), dtype=float64)
# ****
# For epoch  48 , the weights =  tf.Tensor(
# [[-0.04201057]
#  [ 0.48890072]], shape=(2, 1), dtype=float64)
# ****
# For epoch  49 , the weights =  tf.Tensor(
# [[-0.04235391]
#  [ 0.48855738]], shape=(2, 1), dtype=float64)
# ****
# For epoch  50 , the weights =  tf.Tensor(
# [[-0.04248589]
#  [ 0.4884254 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  51 , the weights =  tf.Tensor(
# [[-0.0425983 ]
#  [ 0.48831298]], shape=(2, 1), dtype=float64)
# ****
# For epoch  52 , the weights =  tf.Tensor(
# [[-0.04300785]
#  [ 0.48790344]], shape=(2, 1), dtype=float64)
# ****
# For epoch  53 , the weights =  tf.Tensor(
# [[-0.0424592 ]
#  [ 0.48845209]], shape=(2, 1), dtype=float64)
# ****
# For epoch  54 , the weights =  tf.Tensor(
# [[-0.04259088]
#  [ 0.48832041]], shape=(2, 1), dtype=float64)
# ****
# For epoch  55 , the weights =  tf.Tensor(
# [[-0.04282506]
#  [ 0.48808623]], shape=(2, 1), dtype=float64)
# ****
# For epoch  56 , the weights =  tf.Tensor(
# [[-0.04294989]
#  [ 0.48796139]], shape=(2, 1), dtype=float64)
# ****
# For epoch  57 , the weights =  tf.Tensor(
# [[-0.04288124]
#  [ 0.48803005]], shape=(2, 1), dtype=float64)
# ****
# For epoch  58 , the weights =  tf.Tensor(
# [[-0.04322519]
#  [ 0.4876861 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  59 , the weights =  tf.Tensor(
# [[-0.04359184]
#  [ 0.48731944]], shape=(2, 1), dtype=float64)
# ****
# For epoch  60 , the weights =  tf.Tensor(
# [[-0.04378067]
#  [ 0.48713062]], shape=(2, 1), dtype=float64)
# ****
# For epoch  61 , the weights =  tf.Tensor(
# [[-0.04420814]
#  [ 0.48670315]], shape=(2, 1), dtype=float64)
# ****
# For epoch  62 , the weights =  tf.Tensor(
# [[-0.04433262]
#  [ 0.48657866]], shape=(2, 1), dtype=float64)
# ****
# For epoch  63 , the weights =  tf.Tensor(
# [[-0.04437446]
#  [ 0.48653683]], shape=(2, 1), dtype=float64)
# ****
# For epoch  64 , the weights =  tf.Tensor(
# [[-0.04458295]
#  [ 0.48632833]], shape=(2, 1), dtype=float64)
# ****
# For epoch  65 , the weights =  tf.Tensor(
# [[-0.04501669]
#  [ 0.4858946 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  66 , the weights =  tf.Tensor(
# [[-0.04537485]
#  [ 0.48553644]], shape=(2, 1), dtype=float64)
# ****
# For epoch  67 , the weights =  tf.Tensor(
# [[-0.04546971]
#  [ 0.48544158]], shape=(2, 1), dtype=float64)
# ****
# For epoch  68 , the weights =  tf.Tensor(
# [[-0.04583865]
#  [ 0.48507263]], shape=(2, 1), dtype=float64)
# ****
# For epoch  69 , the weights =  tf.Tensor(
# [[-0.04572678]
#  [ 0.4851845 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  70 , the weights =  tf.Tensor(
# [[-0.04588424]
#  [ 0.48502705]], shape=(2, 1), dtype=float64)
# ****
# For epoch  71 , the weights =  tf.Tensor(
# [[-0.04598493]
#  [ 0.48492635]], shape=(2, 1), dtype=float64)
# ****
# For epoch  72 , the weights =  tf.Tensor(
# [[-0.04622558]
#  [ 0.48468571]], shape=(2, 1), dtype=float64)
# ****
# For epoch  73 , the weights =  tf.Tensor(
# [[-0.0466341 ]
#  [ 0.48427718]], shape=(2, 1), dtype=float64)
# ****
# For epoch  74 , the weights =  tf.Tensor(
# [[-0.04658668]
#  [ 0.48432461]], shape=(2, 1), dtype=float64)
# ****
# For epoch  75 , the weights =  tf.Tensor(
# [[-0.04679126]
#  [ 0.48412003]], shape=(2, 1), dtype=float64)
# ****
# For epoch  76 , the weights =  tf.Tensor(
# [[-0.04679743]
#  [ 0.48411386]], shape=(2, 1), dtype=float64)
# ****
# For epoch  77 , the weights =  tf.Tensor(
# [[-0.04705245]
#  [ 0.48385884]], shape=(2, 1), dtype=float64)
# ****
# For epoch  78 , the weights =  tf.Tensor(
# [[-0.047238  ]
#  [ 0.48367328]], shape=(2, 1), dtype=float64)
# ****
# For epoch  79 , the weights =  tf.Tensor(
# [[-0.04701736]
#  [ 0.48389393]], shape=(2, 1), dtype=float64)
# ****
# For epoch  80 , the weights =  tf.Tensor(
# [[-0.04733174]
#  [ 0.48357955]], shape=(2, 1), dtype=float64)
# ****
# For epoch  81 , the weights =  tf.Tensor(
# [[-0.04730974]
#  [ 0.48360154]], shape=(2, 1), dtype=float64)
# ****
# For epoch  82 , the weights =  tf.Tensor(
# [[-0.04763332]
#  [ 0.48327796]], shape=(2, 1), dtype=float64)
# ****
# For epoch  83 , the weights =  tf.Tensor(
# [[-0.04763232]
#  [ 0.48327896]], shape=(2, 1), dtype=float64)
# ****
# For epoch  84 , the weights =  tf.Tensor(
# [[-0.0479256 ]
#  [ 0.48298569]], shape=(2, 1), dtype=float64)
# ****
# For epoch  85 , the weights =  tf.Tensor(
# [[-0.04832655]
#  [ 0.48258474]], shape=(2, 1), dtype=float64)
# ****
# For epoch  86 , the weights =  tf.Tensor(
# [[-0.04801657]
#  [ 0.48289472]], shape=(2, 1), dtype=float64)
# ****
# For epoch  87 , the weights =  tf.Tensor(
# [[-0.04818318]
#  [ 0.48272811]], shape=(2, 1), dtype=float64)
# ****
# For epoch  88 , the weights =  tf.Tensor(
# [[-0.04820671]
#  [ 0.48270457]], shape=(2, 1), dtype=float64)
# ****
# For epoch  89 , the weights =  tf.Tensor(
# [[-0.04781267]
#  [ 0.48309862]], shape=(2, 1), dtype=float64)
# ****
# For epoch  90 , the weights =  tf.Tensor(
# [[-0.0481275 ]
#  [ 0.48278379]], shape=(2, 1), dtype=float64)
# ****
# For epoch  91 , the weights =  tf.Tensor(
# [[-0.04838454]
#  [ 0.48252675]], shape=(2, 1), dtype=float64)
# ****
# For epoch  92 , the weights =  tf.Tensor(
# [[-0.04835577]
#  [ 0.48255551]], shape=(2, 1), dtype=float64)
# ****
# For epoch  93 , the weights =  tf.Tensor(
# [[-0.04840166]
#  [ 0.48250962]], shape=(2, 1), dtype=float64)
# ****
# For epoch  94 , the weights =  tf.Tensor(
# [[-0.04839365]
#  [ 0.48251763]], shape=(2, 1), dtype=float64)
# ****
# For epoch  95 , the weights =  tf.Tensor(
# [[-0.04819676]
#  [ 0.48271453]], shape=(2, 1), dtype=float64)
# ****
# For epoch  96 , the weights =  tf.Tensor(
# [[-0.04840881]
#  [ 0.48250248]], shape=(2, 1), dtype=float64)
# ****
# For epoch  97 , the weights =  tf.Tensor(
# [[-0.04846995]
#  [ 0.48244134]], shape=(2, 1), dtype=float64)
# ****
# For epoch  98 , the weights =  tf.Tensor(
# [[-0.04887065]
#  [ 0.48204064]], shape=(2, 1), dtype=float64)
# ****
# For epoch  99 , the weights =  tf.Tensor(
# [[-0.04888216]
#  [ 0.48202913]], shape=(2, 1), dtype=float64)
# ****
# For epoch  100 , the weights =  tf.Tensor(
# [[-0.04923426]
#  [ 0.48167703]], shape=(2, 1), dtype=float64)
# ****
# For epoch  101 , the weights =  tf.Tensor(
# [[-0.04925294]
#  [ 0.48165834]], shape=(2, 1), dtype=float64)
# ****
# For epoch  102 , the weights =  tf.Tensor(
# [[-0.04928268]
#  [ 0.48162861]], shape=(2, 1), dtype=float64)
# ****
# For epoch  103 , the weights =  tf.Tensor(
# [[-0.04954581]
#  [ 0.48136548]], shape=(2, 1), dtype=float64)
# ****
# For epoch  104 , the weights =  tf.Tensor(
# [[-0.04987692]
#  [ 0.48103437]], shape=(2, 1), dtype=float64)
# ****
# For epoch  105 , the weights =  tf.Tensor(
# [[-0.04983828]
#  [ 0.48107301]], shape=(2, 1), dtype=float64)
# ****
# For epoch  106 , the weights =  tf.Tensor(
# [[-0.049786  ]
#  [ 0.48112529]], shape=(2, 1), dtype=float64)
# ****
# For epoch  107 , the weights =  tf.Tensor(
# [[-0.05038345]
#  [ 0.48052784]], shape=(2, 1), dtype=float64)
# ****
# For epoch  108 , the weights =  tf.Tensor(
# [[-0.05034576]
#  [ 0.48056552]], shape=(2, 1), dtype=float64)
# ****
# For epoch  109 , the weights =  tf.Tensor(
# [[-0.04983737]
#  [ 0.48107391]], shape=(2, 1), dtype=float64)
# ****
# For epoch  110 , the weights =  tf.Tensor(
# [[-0.04990262]
#  [ 0.48100867]], shape=(2, 1), dtype=float64)
# ****
# For epoch  111 , the weights =  tf.Tensor(
# [[-0.05016804]
#  [ 0.48074325]], shape=(2, 1), dtype=float64)
# ****
# For epoch  112 , the weights =  tf.Tensor(
# [[-0.05056387]
#  [ 0.48034742]], shape=(2, 1), dtype=float64)
# ****
# For epoch  113 , the weights =  tf.Tensor(
# [[-0.05072523]
#  [ 0.48018606]], shape=(2, 1), dtype=float64)
# ****
# For epoch  114 , the weights =  tf.Tensor(
# [[-0.05075003]
#  [ 0.48016126]], shape=(2, 1), dtype=float64)
# ****
# For epoch  115 , the weights =  tf.Tensor(
# [[-0.05050677]
#  [ 0.48040452]], shape=(2, 1), dtype=float64)
# ****
# For epoch  116 , the weights =  tf.Tensor(
# [[-0.05068269]
#  [ 0.48022859]], shape=(2, 1), dtype=float64)
# ****
# For epoch  117 , the weights =  tf.Tensor(
# [[-0.0510683 ]
#  [ 0.47984299]], shape=(2, 1), dtype=float64)
# ****
# For epoch  118 , the weights =  tf.Tensor(
# [[-0.05140519]
#  [ 0.47950609]], shape=(2, 1), dtype=float64)
# ****
# For epoch  119 , the weights =  tf.Tensor(
# [[-0.05145423]
#  [ 0.47945706]], shape=(2, 1), dtype=float64)
# ****
# For epoch  120 , the weights =  tf.Tensor(
# [[-0.051869  ]
#  [ 0.47904229]], shape=(2, 1), dtype=float64)
# ****
# For epoch  121 , the weights =  tf.Tensor(
# [[-0.05229229]
#  [ 0.478619  ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  122 , the weights =  tf.Tensor(
# [[-0.05219026]
#  [ 0.47872102]], shape=(2, 1), dtype=float64)
# ****
# For epoch  123 , the weights =  tf.Tensor(
# [[-0.05265932]
#  [ 0.47825197]], shape=(2, 1), dtype=float64)
# ****
# For epoch  124 , the weights =  tf.Tensor(
# [[-0.05295701]
#  [ 0.47795428]], shape=(2, 1), dtype=float64)
# ****
# For epoch  125 , the weights =  tf.Tensor(
# [[-0.05288698]
#  [ 0.4780243 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  126 , the weights =  tf.Tensor(
# [[-0.05306355]
#  [ 0.47784773]], shape=(2, 1), dtype=float64)
# ****
# For epoch  127 , the weights =  tf.Tensor(
# [[-0.05296515]
#  [ 0.47794613]], shape=(2, 1), dtype=float64)
# ****
# For epoch  128 , the weights =  tf.Tensor(
# [[-0.05293461]
#  [ 0.47797668]], shape=(2, 1), dtype=float64)
# ****
# For epoch  129 , the weights =  tf.Tensor(
# [[-0.05300818]
#  [ 0.47790311]], shape=(2, 1), dtype=float64)
# ****
# For epoch  130 , the weights =  tf.Tensor(
# [[-0.05318251]
#  [ 0.47772877]], shape=(2, 1), dtype=float64)
# ****
# For epoch  131 , the weights =  tf.Tensor(
# [[-0.05353777]
#  [ 0.47737352]], shape=(2, 1), dtype=float64)
# ****
# For epoch  132 , the weights =  tf.Tensor(
# [[-0.05374775]
#  [ 0.47716354]], shape=(2, 1), dtype=float64)
# ****
# For epoch  133 , the weights =  tf.Tensor(
# [[-0.05403424]
#  [ 0.47687705]], shape=(2, 1), dtype=float64)
# ****
# For epoch  134 , the weights =  tf.Tensor(
# [[-0.05417929]
#  [ 0.47673199]], shape=(2, 1), dtype=float64)
# ****
# For epoch  135 , the weights =  tf.Tensor(
# [[-0.05468262]
#  [ 0.47622867]], shape=(2, 1), dtype=float64)
# ****
# For epoch  136 , the weights =  tf.Tensor(
# [[-0.05492605]
#  [ 0.47598524]], shape=(2, 1), dtype=float64)
# ****
# For epoch  137 , the weights =  tf.Tensor(
# [[-0.0546482 ]
#  [ 0.47626309]], shape=(2, 1), dtype=float64)
# ****
# For epoch  138 , the weights =  tf.Tensor(
# [[-0.05458047]
#  [ 0.47633082]], shape=(2, 1), dtype=float64)
# ****
# For epoch  139 , the weights =  tf.Tensor(
# [[-0.05479341]
#  [ 0.47611788]], shape=(2, 1), dtype=float64)
# ****
# For epoch  140 , the weights =  tf.Tensor(
# [[-0.05480079]
#  [ 0.4761105 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  141 , the weights =  tf.Tensor(
# [[-0.05471228]
#  [ 0.47619901]], shape=(2, 1), dtype=float64)
# ****
# For epoch  142 , the weights =  tf.Tensor(
# [[-0.05507623]
#  [ 0.47583506]], shape=(2, 1), dtype=float64)
# ****
# For epoch  143 , the weights =  tf.Tensor(
# [[-0.05529913]
#  [ 0.47561216]], shape=(2, 1), dtype=float64)
# ****
# For epoch  144 , the weights =  tf.Tensor(
# [[-0.05550187]
#  [ 0.47540942]], shape=(2, 1), dtype=float64)
# ****
# For epoch  145 , the weights =  tf.Tensor(
# [[-0.05564325]
#  [ 0.47526804]], shape=(2, 1), dtype=float64)
# ****
# For epoch  146 , the weights =  tf.Tensor(
# [[-0.05578813]
#  [ 0.47512315]], shape=(2, 1), dtype=float64)
# ****
# For epoch  147 , the weights =  tf.Tensor(
# [[-0.05579222]
#  [ 0.47511907]], shape=(2, 1), dtype=float64)
# ****
# For epoch  148 , the weights =  tf.Tensor(
# [[-0.05590449]
#  [ 0.47500679]], shape=(2, 1), dtype=float64)
# ****
# For epoch  149 , the weights =  tf.Tensor(
# [[-0.05613116]
#  [ 0.47478013]], shape=(2, 1), dtype=float64)
# ****
# For epoch  150 , the weights =  tf.Tensor(
# [[-0.05602637]
#  [ 0.47488492]], shape=(2, 1), dtype=float64)
# ****
# For epoch  151 , the weights =  tf.Tensor(
# [[-0.05609637]
#  [ 0.47481492]], shape=(2, 1), dtype=float64)
# ****
# For epoch  152 , the weights =  tf.Tensor(
# [[-0.05606257]
#  [ 0.47484871]], shape=(2, 1), dtype=float64)
# ****
# For epoch  153 , the weights =  tf.Tensor(
# [[-0.05644033]
#  [ 0.47447096]], shape=(2, 1), dtype=float64)
# ****
# For epoch  154 , the weights =  tf.Tensor(
# [[-0.05656206]
#  [ 0.47434922]], shape=(2, 1), dtype=float64)
# ****
# For epoch  155 , the weights =  tf.Tensor(
# [[-0.05651836]
#  [ 0.47439292]], shape=(2, 1), dtype=float64)
# ****
# For epoch  156 , the weights =  tf.Tensor(
# [[-0.05668021]
#  [ 0.47423108]], shape=(2, 1), dtype=float64)
# ****
# For epoch  157 , the weights =  tf.Tensor(
# [[-0.05670638]
#  [ 0.47420491]], shape=(2, 1), dtype=float64)
# ****
# For epoch  158 , the weights =  tf.Tensor(
# [[-0.05671363]
#  [ 0.47419766]], shape=(2, 1), dtype=float64)
# ****
# For epoch  159 , the weights =  tf.Tensor(
# [[-0.05667536]
#  [ 0.47423592]], shape=(2, 1), dtype=float64)
# ****
# For epoch  160 , the weights =  tf.Tensor(
# [[-0.0569133 ]
#  [ 0.47399799]], shape=(2, 1), dtype=float64)
# ****
# For epoch  161 , the weights =  tf.Tensor(
# [[-0.05712498]
#  [ 0.47378631]], shape=(2, 1), dtype=float64)
# ****
# For epoch  162 , the weights =  tf.Tensor(
# [[-0.05694217]
#  [ 0.47396912]], shape=(2, 1), dtype=float64)
# ****
# For epoch  163 , the weights =  tf.Tensor(
# [[-0.05751209]
#  [ 0.4733992 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  164 , the weights =  tf.Tensor(
# [[-0.05785063]
#  [ 0.47306066]], shape=(2, 1), dtype=float64)
# ****
# For epoch  165 , the weights =  tf.Tensor(
# [[-0.05789425]
#  [ 0.47301703]], shape=(2, 1), dtype=float64)
# ****
# For epoch  166 , the weights =  tf.Tensor(
# [[-0.05820164]
#  [ 0.47270965]], shape=(2, 1), dtype=float64)
# ****
# For epoch  167 , the weights =  tf.Tensor(
# [[-0.05838846]
#  [ 0.47252283]], shape=(2, 1), dtype=float64)
# ****
# For epoch  168 , the weights =  tf.Tensor(
# [[-0.0584594 ]
#  [ 0.47245188]], shape=(2, 1), dtype=float64)
# ****
# For epoch  169 , the weights =  tf.Tensor(
# [[-0.05895582]
#  [ 0.47195547]], shape=(2, 1), dtype=float64)
# ****
# For epoch  170 , the weights =  tf.Tensor(
# [[-0.05914654]
#  [ 0.47176475]], shape=(2, 1), dtype=float64)
# ****
# For epoch  171 , the weights =  tf.Tensor(
# [[-0.05938675]
#  [ 0.47152454]], shape=(2, 1), dtype=float64)
# ****
# For epoch  172 , the weights =  tf.Tensor(
# [[-0.05944165]
#  [ 0.47146964]], shape=(2, 1), dtype=float64)
# ****
# For epoch  173 , the weights =  tf.Tensor(
# [[-0.05970993]
#  [ 0.47120136]], shape=(2, 1), dtype=float64)
# ****
# For epoch  174 , the weights =  tf.Tensor(
# [[-0.05959339]
#  [ 0.4713179 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  175 , the weights =  tf.Tensor(
# [[-0.06023947]
#  [ 0.47067181]], shape=(2, 1), dtype=float64)
# ****
# For epoch  176 , the weights =  tf.Tensor(
# [[-0.06016688]
#  [ 0.47074441]], shape=(2, 1), dtype=float64)
# ****
# For epoch  177 , the weights =  tf.Tensor(
# [[-0.06087043]
#  [ 0.47004085]], shape=(2, 1), dtype=float64)
# ****
# For epoch  178 , the weights =  tf.Tensor(
# [[-0.06093792]
#  [ 0.46997336]], shape=(2, 1), dtype=float64)
# ****
# For epoch  179 , the weights =  tf.Tensor(
# [[-0.06072858]
#  [ 0.4701827 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  180 , the weights =  tf.Tensor(
# [[-0.06086756]
#  [ 0.47004373]], shape=(2, 1), dtype=float64)
# ****
# For epoch  181 , the weights =  tf.Tensor(
# [[-0.06104163]
#  [ 0.46986966]], shape=(2, 1), dtype=float64)
# ****
# For epoch  182 , the weights =  tf.Tensor(
# [[-0.06116282]
#  [ 0.46974846]], shape=(2, 1), dtype=float64)
# ****
# For epoch  183 , the weights =  tf.Tensor(
# [[-0.06126965]
#  [ 0.46964164]], shape=(2, 1), dtype=float64)
# ****
# For epoch  184 , the weights =  tf.Tensor(
# [[-0.06075152]
#  [ 0.47015977]], shape=(2, 1), dtype=float64)
# ****
# For epoch  185 , the weights =  tf.Tensor(
# [[-0.06118233]
#  [ 0.46972896]], shape=(2, 1), dtype=float64)
# ****
# For epoch  186 , the weights =  tf.Tensor(
# [[-0.06119604]
#  [ 0.46971525]], shape=(2, 1), dtype=float64)
# ****
# For epoch  187 , the weights =  tf.Tensor(
# [[-0.06126333]
#  [ 0.46964795]], shape=(2, 1), dtype=float64)
# ****
# For epoch  188 , the weights =  tf.Tensor(
# [[-0.06107289]
#  [ 0.4698384 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  189 , the weights =  tf.Tensor(
# [[-0.06140016]
#  [ 0.46951113]], shape=(2, 1), dtype=float64)
# ****
# For epoch  190 , the weights =  tf.Tensor(
# [[-0.06186594]
#  [ 0.46904535]], shape=(2, 1), dtype=float64)
# ****
# For epoch  191 , the weights =  tf.Tensor(
# [[-0.06222848]
#  [ 0.4686828 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  192 , the weights =  tf.Tensor(
# [[-0.06260547]
#  [ 0.46830582]], shape=(2, 1), dtype=float64)
# ****
# For epoch  193 , the weights =  tf.Tensor(
# [[-0.06243265]
#  [ 0.46847863]], shape=(2, 1), dtype=float64)
# ****
# For epoch  194 , the weights =  tf.Tensor(
# [[-0.06278487]
#  [ 0.46812641]], shape=(2, 1), dtype=float64)
# ****
# For epoch  195 , the weights =  tf.Tensor(
# [[-0.06314048]
#  [ 0.46777081]], shape=(2, 1), dtype=float64)
# ****
# For epoch  196 , the weights =  tf.Tensor(
# [[-0.06336109]
#  [ 0.4675502 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  197 , the weights =  tf.Tensor(
# [[-0.06351519]
#  [ 0.4673961 ]], shape=(2, 1), dtype=float64)
# ****
# For epoch  198 , the weights =  tf.Tensor(
# [[-0.06414557]
#  [ 0.46676572]], shape=(2, 1), dtype=float64)
# ****
# For epoch  199 , the weights =  tf.Tensor(
# [[-0.0641213 ]
#  [ 0.46678999]], shape=(2, 1), dtype=float64)
# ****
# For epoch  200 , the weights =  tf.Tensor(
# [[-0.06411003]
#  [ 0.46680125]], shape=(2, 1), dtype=float64)

# %% [markdown]
# Phew! Observed how weights and bias correct themselves on each iteration, and each epoch? It's a long process!

# %% [markdown]
# Let's observe how the loss dropped over a period of time- on the y-axis we have the loss (mean squared error), and epochs on the x-axis

# %%
import matplotlib.pyplot as plt
time_axis = range(1,len(err)+1)
plt.plot(  time_axis, err)
plt.show()

# %% [markdown]
# After this, we can locate the point on the graph with minimum y (because this is an error). That's the point at which we can then retrain the model.

# %% [markdown]
# **Conclusion**

# %% [markdown]
# In this module we achieved the following:
#
#
#
# *   Revised the model training process
# *   Simulated the model training
# *   Observed inbuilt TensorFlow functions
# *   Initialized weights and bias
# *   Observed their updates over iterations and epochs
# *   Calculated and plotted the errors over epochs
